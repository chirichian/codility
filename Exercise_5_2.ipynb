# %%
from IPython.display import Image, display
display(Image(filename='./Exercise_5_2.png'))

# %% [markdown]
# # Solution

# %% [markdown]
# get pair values to compute divisivility

# %%
def solution(A,B,K):
    array = range(A,B+1)
    count = 0 
    for val in array:
        print(val)
        if val%K==0:
            count+=1
    return count

# %%
def solution(A,B,K):
    array = range(A,B+1,K)
    count = 0 
    for val in array:
        print(val)
        if val%K==0:
            count+=1
    return count
